# %%
import networkx as nx
import os
import matplotlib.pyplot as plt
import numpy as np
import scipy.sparse.linalg

# %%
path = r'D:\John_William\Universidad\UNAM\2022-2\TSFCII(Teoria)_Ciencia_redes\Codigos\datasets\retweet-digraph.edges'
G = nx.read_weighted_edgelist(path)

# %%
nx.is_directed(G)
# Out:
# False

# %%
nx.is_weighted(G)
# Out:
# True

# %%
H= nx.read_edgelist(path,
  data=(('weight',int),), create_using=nx.DiGraph())

# %%
print(H.edges(data=True))
nx.draw(H)
plt.show()
# Out:
# [('n1', 'n15743', {'weight': 1.0}), ('n1', 'n5410', {'weight': 1.0}), ('n1', 'n5822', {'weight': 1.0}), ('n15743', 'n7114', {'weight': 6.0}), ('n15743', 'n7578', {'weight': 1.0}), ('n15743', 'n6213', {'weight': 1.0}), ('n15743', 'n754', {'weight': 1.0}), ('n15743', 'n17736', {'weight': 1.0}), ('n15743', 'n9691', {'weight': 1.0}), ('n15743', 'n11674', {'weight': 3.0}), ('n15743', 'n11342', {'weight': 1.0}), ('n15743', 'n4075', {'weight': 1.0}), ('n15743', 'n14414', {'weight': 1.0}), ('n15743', 'n3143', {'weight': 1.0}), ('n15743', 'n12464', {'weight': 1.0}), ('n15743', 'n12591', {'weight': 1.0}), ('n5410', 'n8556', {'weight': 1.0}), ('n5410', 'n5770', {'weight': 1.0}), ('n5410', 'n11687', {'weight': 1.0}), ('n5410', 'n5792', {'weight': 1.0}), ('n5410', 'n12131', {'weight': 1.0}), ('n5410', 'n10426', {'weight': 1.0}), ('n5410', 'n13991', {'weight': 1.0}), ('n7114', 'n1306', {'weight': 1.0}), ('n7578', 'n1490', {'weight': 1.0}), ('n7578', 'n9691', {'weight': 2.0}), ('n7578', 'n13066', {
# ...

# %%
nx.is_weighted(H)
# Out:
# True

# %%
nx.is_directed(H)
# Out:
# True

# %%
nx.clustering(H)
# Out:
# {'n1': 0,
#  'n15743': 0.038461538461538464,
#  'n5410': 0.017857142857142856,
#  'n7114': 0,
#  'n7578': 0.026888039964736998,
#  'n6213': 0.028169014084507043,
#  'n754': 0,
#  'n17736': 0.02046783625730994,
#  'n2': 0,
#  'n16701': 0.011586452762923352,
#  'n4': 0,
#  'n979': 0,
#  'n7': 0,
#  'n3000': 0.10227272727272728,
#  'n8166': 0,
#  'n9332': 0.05555555555555555,
#  'n6964': 0.02844950213371266,
#  'n2851': 0.1,
#  'n9867': 0,
#  'n10524': 0,
#  'n17127': 0.10185185185185185,
#  'n16794': 0.09090909090909091,
#  'n9893': 0.020833333333333332,
#  'n16137': 0.15,
#  'n18297': 0.03205128205128205,
#  'n8608': 0,
#  'n1699': 0,
#  'n10893': 0.016666666666666666,
#  'n4949': 0.015293118096856415,
#  'n16139': 0,
#  'n11865': 0.032294709509899384,
#  'n9': 0,
#  'n18305': 0,
#  'n8102': 0.009523809523809525,
#  'n3685': 0,
#  'n3489': 0.03571428571428571,
#  'n1888': 0.03293161434977578,
#  'n4154': 0.029239766081871343,
#  'n11924': 0.00909090909090909,
# ...

# %%
nx.average_clustering(H)
# Out:
# 0.014210047351115541

# %%
nx.laplacian_matrix(H)
#array1 = np.matrix(nx.laplacian_matrix(G))
# Out:
# ---------------------------------------------------------------------------
# NetworkXNotImplemented                    Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9384/2123329573.py in <module>
# ----> 1 nx.laplacian_matrix(H)
#       2 #array1 = np.matrix(nx.laplacian_matrix(G))
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\networkx\utils\decorators.py in argmap_laplacian_matrix_22(G, nodelist, weight)
#       1 from collections import defaultdict
#       2 from os.path import splitext
# ----> 3 from contextlib import contextmanager
#       4 from pathlib import Path
#       5 import warnings
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\networkx\utils\decorators.py in _not_implemented_for(g)
#      85             dval is None or dval == g.is_directed()
#      86         ):
# ---> 87             raise nx.NetworkXNotImplemented(errmsg)
#      88
#      89         return g
#
# ...

# %%
for i in array1:print(i)
# Out:
# [[<18470x18470 sparse matrix of type '<class 'numpy.float64'>'
#   	with 114576 stored elements in Compressed Sparse Row format>]]

# %%
J=nx.read_weighted_edgelist(path)
nx.nodes(J)
# Out:
# NodeView(('n1', 'n15743', 'n5410', 'n7114', 'n7578', 'n6213', 'n754', 'n17736', 'n2', 'n16701', 'n4', 'n979', 'n7', 'n3000', 'n8166', 'n9332', 'n6964', 'n2851', 'n9867', 'n10524', 'n17127', 'n16794', 'n9893', 'n16137', 'n18297', 'n8608', 'n1699', 'n10893', 'n4949', 'n16139', 'n11865', 'n9', 'n18305', 'n8102', 'n3685', 'n3489', 'n1888', 'n4154', 'n11924', 'n11515', 'n2440', 'n11833', 'n13775', 'n9942', 'n5566', 'n10612', 'n17291', 'n10990', 'n1219', 'n15', 'n3731', 'n18242', 'n14786', 'n6614', 'n7340', 'n372', 'n239', 'n16', 'n10951', 'n20', 'n9179', 'n17960', 'n6655', 'n8796', 'n8719', 'n15966', 'n5797', 'n17021', 'n772', 'n2701', 'n6012', 'n2969', 'n7058', 'n15614', 'n3887', 'n17673', 'n3176', 'n784', 'n834', 'n13887', 'n8447', 'n6801', 'n16387', 'n12351', 'n8556', 'n4172', 'n9198', 'n9700', 'n9935', 'n6651', 'n13159', 'n18215', 'n3982', 'n12220', 'n12977', 'n10053', 'n1393', 'n9017', 'n9038', 'n17537', 'n4939', 'n99', 'n15162', 'n16723', 'n10862', 'n13652', 'n5461', 'n4601', 'n1488
# ...

# %%
nx.laplacian_matrix(J)
# Out:
# <18470x18470 sparse matrix of type '<class 'numpy.float64'>'
# 	with 114576 stored elements in Compressed Sparse Row format>

# %%
nx.clustering(J)
# Out:
# {'n1': 0,
#  'n15743': 0.06593406593406594,
#  'n5410': 0.03571428571428571,
#  'n7114': 0,
#  'n7578': 0.0526006464883926,
#  'n6213': 0.04627766599597585,
#  'n754': 0,
#  'n17736': 0.04093567251461988,
#  'n2': 0,
#  'n16701': 0.023172905525846704,
#  'n4': 0,
#  'n979': 0,
#  'n7': 0,
#  'n3000': 0.16666666666666666,
#  'n8166': 0,
#  'n9332': 0.1111111111111111,
#  'n6964': 0.05547652916073969,
#  'n2851': 0.2,
#  'n9867': 0,
#  'n10524': 0,
#  'n17127': 0.17777777777777778,
#  'n16794': 0.16363636363636364,
#  'n9893': 0.04057971014492753,
#  'n16137': 0.3,
#  'n18297': 0.0641025641025641,
#  'n8608': 0,
#  'n1699': 0,
#  'n10893': 0.03333333333333333,
#  'n4949': 0.025303643724696356,
#  'n16139': 0,
#  'n11865': 0.06199285946121389,
#  'n9': 0,
#  'n18305': 0,
#  'n8102': 0.01904761904761905,
#  'n3685': 0,
#  'n3489': 0.07142857142857142,
#  'n1888': 0.0526006464883926,
#  'n4154': 0.05847953216374269,
#  'n11924': 0.01818181818181818,
#  'n11515': 0.03636363636363636,
# ...

# %%
nx.is_weighted(J)
# Out:
# True

# %%
nx.is_directed(J)
# Out:
# False

# %%
J = nx.read_edgelist(path,create_using=nx.DiGraph(),data=(('weight',float),),edgetype='weight')#Este sirve

# %%
g = nx.read_edgelist(path, nodetype=str,
  data=(('weight',float),), create_using=nx.DiGraph())

# %%
nx.is_directed(g)
# Out:
# True

# %%
nx.is_weighted(g)
# Out:
# True

# %%
nx.directed_laplacian_matrix(g,weight='weight')
# Out:
# matrix([[ 9.99997293e-01, -1.33300409e-01, -1.48997349e-01, ...,
#          -2.80379778e-05, -2.80379778e-05, -2.80379778e-05],
#         [-1.33300409e-01,  9.99997293e-01, -2.57380948e-05, ...,
#          -1.74135613e-05, -1.74135613e-05, -1.74135613e-05],
#         [-1.48997349e-01, -2.57380948e-05,  9.99945858e-01, ...,
#          -6.05453661e-05, -6.05453661e-05, -6.05453661e-05],
#         ...,
#         [-2.80379778e-05, -1.74135613e-05, -6.05453661e-05, ...,
#           9.99945858e-01, -5.41418517e-05, -5.41418517e-05],
#         [-2.80379778e-05, -1.74135613e-05, -6.05453661e-05, ...,
#          -5.41418517e-05,  9.99945858e-01, -5.41418517e-05],
#         [-2.80379778e-05, -1.74135613e-05, -6.05453661e-05, ...,
#          -5.41418517e-05, -5.41418517e-05,  9.99945858e-01]])
